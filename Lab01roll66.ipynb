# %% [markdown]
# <a href="https://colab.research.google.com/github/Junaiddali/Data-Science-and-Analytics/blob/main/Lab01roll66.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""TASK 1
"""
name = "shahzad"
rollno = 67



print("my name is : ".format(name))
print("my roll number is {}".format(rollno))
# Out:
# my name is :
# my roll number is 67

# %%
"""TASK 2
"""

text = "Hello, World!"



# Capitalizing the first letter of the string
print("Capitalized:", text.capitalize())

# Capitalizing the first letter of the string
print("Capitalized:", text.casefold())

centered_text = text.center(20, "*")
print("Centered text:", centered_text)


# Counting occurrences of a substring in the string
print("Count of 'l':", text.count("l"))


text = "Hello, World!"

# Encoding the string using UTF-8
encoded_text = text.encode("utf-8")
print("Encoded text:", encoded_text)



# checks if the string starts with a specific substring
print("Starts with 'Hello':", text.startswith("Hello"))

# Checking if the string ends with a specific substring
print("Ends with 'World!':", text.endswith("World!"))
# Out:
# Capitalized: Hello, world!
# Capitalized: hello, world!
# Centered text: ***Hello, World!****
# Count of 'l': 3
# Encoded text: b'Hello, World!'
# Starts with 'Hello': True
# Ends with 'World!': True

# %%
"""TASK 3
"""

month = 4
days_in_month = [31,28,31,30,31,30,31,31,30,31,30,31]
# use list indexing to determine the number of days in month

days = days_in_month[month-1]

print(days)
# Out:
# 30

# %%
"""TASK 4
"""

eclipse_dates = ['June 21, 2001', 'December 4, 2002', 'November 23,2003',
 'March 29, 2006', 'August 1, 2008', 'July 22, 2009',
 'July 11, 2010', 'November 13, 2012', 'March 20,2015',
 'March 9, 2016']


# TODO: Modify this line so it prints the last three elements of the
print(eclipse_dates[7:10])
# Out:
# ['November 13, 2012', 'March 20,2015', 'March 9, 2016']

# %%
"""TASK 5
"""

nested_dict = {
    'Junaid Ali': {
        'rollno': '009',
        'Batch': '20',
        'gpa': '3.5'
    },
    'Abdullah': {
        'rollno': '15',
        'gpa': '4'
    },
    'key3': {
        'Ahsan': {
            'rollno': '81',
            'gpa': '3.4'
        }
    }
}

print(nested_dict)
# Out:
# {'Junaid Ali': {'rollno': '009', 'Batch': '20', 'gpa': '3.5'}, 'Abdullah': {'rollno': '15', 'gpa': '4'}, 'key3': {'Ahsan': {'rollno': '81', 'gpa': '3.4'}}}
